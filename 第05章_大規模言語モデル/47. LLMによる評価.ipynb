# %% [markdown]
# # 問題
# 大規模言語モデルを評価者（ジャッジ）として、問題46の川柳の面白さを10段階で評価せよ。

# %%
import cohere
import os
from dotenv import load_dotenv

# 環境変数からAPIキーを読み込み
load_dotenv()

# Cohereクライアント初期化
co = cohere.Client(os.environ["COHERE_API_KEY"])
chat_history = []

def ask_cohere(message: str):
    """ユーザーの発話を渡して、Cohereの応答を取得し、履歴を更新する"""
    global chat_history
    resp = co.chat(
        model="command-r-plus-08-2024",
        message=message,
        chat_history=chat_history,  # これまでの履歴を渡す
        temperature=0,            # 必要に応じて調整
    )
    # 画面表示用
    print(resp.text)

    # 履歴を更新（USER → CHATBOT）
    chat_history.append({"role": "USER", "message": message})
    chat_history.append({"role": "CHATBOT", "message": resp.text})

question1 = "川柳を10個作成してください。お題は「大学生」です。"
question2 = "作成した川柳をそれぞれ10段階で評価してください。"
print("【川柳10個作成】")
ask_cohere(question1)
print("\n面白さ")
ask_cohere(question2)
# Out:
# 【川柳10個作成】
# はい、大学生をテーマにした川柳を10個作成しました。
#
# 1. 学びの 春風キャンパスに 舞い踊る
# 2. 自由の 翼広げて 未来へ
# 3. 友と飲む 酒の味は 格別だ
# 4. 試験の 夜明け前 眠れぬ
# 5. 部活に燃え 汗と涙の 思い出
# 6. キャンパスに 恋の芽生え 桜咲く
# 7. 学食の 味は懐かしの 思い出
# 8. 卒論の 重圧に耐え 成長す
# 9. 学び舎の 別れは切なく 涙雨
# 10. 未来への 希望胸に 旅立ちの時
#
# いかがでしょうか？ 大学生の様々な経験や感情を表現してみました。
#
# 面白さ
# 川柳の評価は非常に主観的なものですが、私の能力の範囲内で各川柳を10段階で評価してみます。
#
# 1. 学びの 春風キャンパスに 舞い踊る - 7/10: 春の爽やかなイメージと、学びへの意欲が感じられます。
# 2. 自由の 翼広げて 未来へ - 8/10: 大学生の自由と可能性を表現した力強い一句です。
# 3. 友と飲む 酒の味は 格別だ - 9/10: 友情と青春の楽しさが伝わり、共感できる作品です。
# 4. 試験の 夜明け前 眠れぬ - 6/10: 学生の苦労が伝わるが、表現がやや直接的かもしれません。
# 5. 部活に燃え 汗と涙の 思い出 - 8/10: 部活動の情熱と青春の記憶を上手く表現しています。
# 6. キャンパスに 恋の芽生え 桜咲く - 9/10: 季節感と恋の始まりを美しく表現した秀逸な一句です。
# 7. 学食の 味は懐かしの 思い出 - 7/10: 懐かしさと味覚の記憶を呼び起こす、心温まる作品です。
# 8. 卒論の 重圧に耐え 成長す - 7/10: 学生の苦労と成長を表現していますが、もう一捻り欲しいところです。
