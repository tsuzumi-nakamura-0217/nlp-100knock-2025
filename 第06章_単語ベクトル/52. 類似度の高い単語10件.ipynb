# %% [markdown]
# # 問題
# “United States”とコサイン類似度が高い10語と、その類似度を出力せよ。

# %%
# United_States と似ている単語を10個
from gensim.models import KeyedVectors
def top10():
  path = "/Users/nakamuratuzumi/Jupyterlab/言語処理100本ノック 2025/第06章_単語ベクトル/GoogleNews-vectors-negative300.bin"

  kv = KeyedVectors.load_word2vec_format(path, binary=True, limit=None)
  similar_words = kv.most_similar("United_States", topn=10)

  for word, score in similar_words:
      print(f"{word}: {score:.4f}")

# %%
top10()
# Out:
# Unites_States: 0.7877
# Untied_States: 0.7541
# United_Sates: 0.7401
# U.S.: 0.7311
# theUnited_States: 0.6404
# America: 0.6178
# UnitedStates: 0.6167
# Europe: 0.6133
# countries: 0.6045
# Canada: 0.6019
